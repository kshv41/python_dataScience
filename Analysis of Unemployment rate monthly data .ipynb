# %% [markdown]
# # Analysis of data on Monthly Unemployment rates.

# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
unrate = pd.read_csv('unrate.csv')

# %% [markdown]
# The data can be downloaded from here- https://drive.google.com/file/d/1A_nNjRQk1pEZ9MK9CjczHiatIFq4B7Vn/view?usp=sharing

# %%
unrate.head(3)
# Out:
#          DATE  VALUE
# 0  1948-01-01    3.4
# 1  1948-02-01    3.8
# 2  1948-03-01    4.0

# %% [markdown]
# Converting the date column to date and time format.

# %%
unrate.loc[:, 'DATE'] = pd.to_datetime(unrate.loc[:, 'DATE'])

# %% [markdown]
# Charting out various values for different months for four years from 1948.

# %%
#Subplots
fig = plt.figure(figsize = (12,20))
for i in range(4):
    ax = fig.add_subplot(4,1,(i+1))
    ax.plot(unrate.iloc[12*i:12*(i+1), :].loc[:, 'DATE'], unrate.iloc[12*i:12*(i+1), :].loc[:, 'VALUE'])
    title = str(1948+ i)
    ax.set_title('Unemployment rate- '+ title)

plt.xlabel('Month')
plt.ylabel('Unemployment rate in percentage')
fig.show()
# Out:
# /Users/madhav/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   # This is added back by InteractiveShellApp.init_path()

# %%
unrate.loc[:, 'MONTH'] = unrate.loc[:, 'DATE']. dt.month

# %%
fig = plt.figure()
color = ['red' , 'black', 'blue', 'green']
for i in range(4):
    label = str(1948 +i )
    plt.plot(unrate.iloc[12*i:12*(i+1), :].loc[:, 'MONTH'], unrate.iloc[12*i:12*(i+1), :].loc[:, 'VALUE'], c= color[i], label = label)
    
plt.title('Montly Unemployment rates')
plt.legend(loc = 'upper left')
plt.ylabel('Unemployment rates %')
plt.xlabel('Months')
plt.show()
